# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
print("1. My lane as an ML task (type)")
print("Task Type: Scoring (Regression)")
print("Reason: Predicting future hospital bed demand produces a numeric value.")
# Out:
# 1. My lane as an ML task (type)
# Task Type: Scoring (Regression)
# Reason: Predicting future hospital bed demand produces a numeric value.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
print("\n2. Target or proxy")
print("Target Variable: target_bed_demand")
print("Label Source: Observed historical hospital bed occupancy.")
# Out:
# 2. Target or proxy
# Target Variable: target_bed_demand
# Label Source: Observed historical hospital bed occupancy.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
print("\n3. Success metric")
print("Metric: Mean Absolute Error (MAE)")
print("Good performance: MAE less than 5 beds per day.")
# Out:
# 3. Success metric
# Metric: Mean Absolute Error (MAE)
# Good performance: MAE less than 5 beds per day.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.DataFrame({
    "date": ["2026-01-01", "2026-01-02", "2026-01-03"],
    "emergency_admissions": [42, 50, 47],
    "scheduled_admissions": [18, 20, 15],
    "discharges": [30, 28, 35],
    "flu_cases": [12, 15, 10],
    "available_staff": [78, 75, 80],
    "occupancy_rate": [0.88, 0.93, 0.85],
    "target_bed_demand": [115, 126, 110]
})

print("\n4. The unit of analysis")
print("One row = One hospital day\n")

print(df.head())
# Out:
# 4. The unit of analysis
# One row = One hospital day
#
#          date  emergency_admissions  scheduled_admissions  discharges  \
# 0  2026-01-01                    42                    18          30
# 1  2026-01-02                    50                    20          28
# 2  2026-01-03                    47                    15          35
#
#    flu_cases  available_staff  occupancy_rate  target_bed_demand
# 0         12               78            0.88                115
# 1         15               75            0.93                126
# 2         10               80            0.85                110

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
print("\n5. Why ML beats a fixed rule here")
print("""
Hospital demand depends on:
- Emergency admissions
- Discharge rates
- Seasonal illnesses
- Staffing levels
- Scheduled surgeries
- Holidays and weekends

These interactions are too complex for simple if-statements,
making machine learning a better approach.
""")
# Out:
# 5. Why ML beats a fixed rule here
#
# Hospital demand depends on:
# - Emergency admissions
# - Discharge rates
# - Seasonal illnesses
# - Staffing levels
# - Scheduled surgeries
# - Holidays and weekends
#
# These interactions are too complex for simple if-statements,
# making machine learning a better approach.

# %%
print("\nSelf-check")
print("[X] ML task type identified")
print("[X] Target variable identified")
print("[X] Success metric defined")
print("[X] Unit of analysis shown")
print("[X] ML justification provided")
print("[X] Output linked to operational decisions")
# Out:
# Self-check
# [X] ML task type identified
# [X] Target variable identified
# [X] Success metric defined
# [X] Unit of analysis shown
# [X] ML justification provided
# [X] Output linked to operational decisions

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
